# %% [markdown]
# # **TikTok Project**
# **Course 2 - Get Started with Python**

# %% [markdown]
# Welcome to the TikTok Project!
#
# You have just started as a data professional at TikTok.
#
# The team is still in the early stages of the project. You have received notice that TikTok's leadership team has approved the project proposal. To gain clear insights to prepare for a claims classification model, TikTok's provided data must be examined to begin the process of exploratory data analysis (EDA).
#
# A notebook was structured and prepared to help you in this project. Please complete the following questions.

# %% [markdown]
# # **Course 2 End-of-course project: Inspect and analyze data**
#
# In this activity, you will examine data provided and prepare it for analysis.
# <br/>
#
# **The purpose** of this project is to investigate and understand the data provided. This activity will:
#
# 1.   Acquaint you with the data
#
# 2.   Compile summary information about the data
#
# 3.   Begin the process of EDA and reveal insights contained in the data
#
# 4.   Prepare you for more in-depth EDA, hypothesis testing, and statistical analysis
#
# **The goal** is to construct a dataframe in Python, perform a cursory inspection of the provided dataset, and inform TikTok data team members of your findings.
# <br/>
# *This activity has three parts:*
#
# **Part 1:** Understand the situation
# * How can you best prepare to understand and organize the provided TikTok information?
#
# **Part 2:** Understand the data
#
# * Create a pandas dataframe for data learning and future exploratory data analysis (EDA) and statistical activities
#
# * Compile summary information about the data to inform next steps
#
# **Part 3:** Understand the variables
#
# * Use insights from your examination of the summary data to guide deeper investigation into variables
#
# <br/>
#
# To complete the activity, follow the instructions and answer the questions below. Then, you will us your responses to these questions and the questions included in the Course 2 PACE Strategy Document to create an executive summary.
#
# Be sure to complete this activity before moving on to Course 3. You can assess your work by comparing the results to a completed exemplar after completing the end-of-course project.

# %% [markdown]
# # **Identify data types and compile summary information**

# %% [markdown]
# Throughout these project notebooks, you'll see references to the problem-solving framework PACE. The following notebook components are labeled with the respective PACE stage: Plan, Analyze, Construct, and Execute.
#
# # **PACE stages**
#
# <img src="images/Pace.png" width="100" height="100" align=left>
#
#    *        [Plan](#scrollTo=psz51YkZVwtN&line=3&uniqifier=1)
#    *        [Analyze](#scrollTo=mA7Mz_SnI8km&line=4&uniqifier=1)
#    *        [Construct](#scrollTo=Lca9c8XON8lc&line=2&uniqifier=1)
#    *        [Execute](#scrollTo=401PgchTPr4E&line=2&uniqifier=1)

# %% [markdown]
# <img src="images/Plan.png" width="100" height="100" align=left>
#
#
# ## **PACE: Plan**
#
# Consider the questions in your PACE Strategy Document and those below to craft your response:

# %% [markdown]
# ### **Task 1. Understand the situation**
#
# *   How can you best prepare to understand and organize the provided information?

# %% [markdown]
# *Begin by exploring your dataset and consider reviewing the Data Dictionary.*
# To prepare, We would explore the dataset using `.head()`, `.info()`, and `.describe()` to get a sense of the structure and values. We’d also review the data dictionary to clearly understand what each column represents and how they relate to the classification goal.

# %% [markdown]
# * What follow-along and self-review codebooks will help you perform this work?

# %% [markdown]
# The most helpful codebooks are the ones that cover data cleaning, identifying null values, converting data types, and creating visualizations. These will guide me through organizing the data and preparing it for analysis.

# %% [markdown]
# * What are some additional activities a resourceful learner would perform before starting to code?

# %% [markdown]
# One would study the dataset and data dictionary carefully, outline a plan for cleaning and organizing the data, think about which features might be useful for the model, and consider the overall goal of classifying claims versus opinions to stay focused.

# %% [markdown]
# <img src="images/Analyze.png" width="100" height="100" align=left>
#
# ## **PACE: Analyze**
#
# Consider the questions in your PACE Strategy Document to reflect on the Analyze stage.

# %% [markdown]
# ### **Task 2a. Imports and data loading**
#
# Start by importing the packages that you will need to load and explore the dataset. Make sure to use the following import statements:
# *   `import pandas as pd`
#
# *   `import numpy as np`

# %%
# Import packages
import pandas as pd
import numpy as np

# %% [markdown]
# Then, load the dataset into a dataframe. Creating a dataframe will help you conduct data manipulation, exploratory data analysis (EDA), and statistical activities.
#
# **Note:** As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# Load dataset into dataframe
data = pd.read_csv("tiktok_dataset.csv")

# %% [markdown]
# ### **Task 2b. Understand the data - Inspect the data**
#
# View and inspect summary information about the dataframe by **coding the following:**
#
# 1. `data.head(10)`
# 2. `data.info()`
# 3. `data.describe()`
#
# *Consider the following questions:*
#
# **Question 1:** When reviewing the first few rows of the dataframe, what do you observe about the data? What does each row represent?
#
# **Question 2:** When reviewing the `data.info()` output, what do you notice about the different variables? Are there any null values? Are all of the variables numeric? Does anything else stand out?
#
# **Question 3:** When reviewing the `data.describe()` output, what do you notice about the distributions of each variable? Are there any questionable values? Does it seem that there are outlier values?

# %%
# Display and examine the first ten rows of the dataframe
data.head(10)

# %%
# Get summary info
data.info()

# %%
summary = pd.DataFrame({
    'Column Name': data.columns,
    'Non-Null Count': data.notnull().sum().values,
    'Null Count': data.isnull().sum().values,
    'Data Type' : data.dtypes.values,
    '% Missing' : ((data.isnull().sum().values / len(data)) * 100).round(2)
})
summary

# %%
# Get summary statistics
data.describe()

# %% [markdown]
# RESPONSE TO QUESTIONS 1-3 HERE

# %% [markdown]
# **Answer 1:** Each row in the dataframe represents a single published TikTok video that has been labeled as either a claim or an opinion. The data includes various attributes about each video, such as its duration, transcription text, author status (e.g., verified or not), and engagement metrics like views, likes, shares, downloads, and comments. Most of the sample rows appear to be labeled as claims and come from unverified users.
#
# **Answer 2:** The dataset contains **19382 rows and 12 columns**. Columns `claim_status`, `video_transcription_text`, `video_view_count`, `video_like_count`, `video_share_count`, `video_download_count`, and `video_comment_count` have **have 298 null values each.**. Most columns are numeric (`float64`/`int64`), the rest are `object` like categorical columns `claim_status`, `verified_status` and `author_ban_status`, and a string column `video_transcription_text`. There is a column named `#` which probably acts as a row ID.
#
# **Answer 3:** Normal values for `video_duration_sec` which ranges from 5 to 60 seconds, as expected for TikTok contents. While the video view counts range from just 20 views to almost 1 million, this isn't a problem—it’s actually normal for TikTok. A few videos go viral or trending, while most don’t get as much attention. This pattern is common on social media and is not considered an error or outlier in a bad way. It's just how platforms like TikTok work. **No clearly invalid values** (like negative counts) are visible, but the skewness suggests we may want to apply transformations or handle outliers during analysis.

# %% [markdown]
# #### Initial Cleaning
# * Replace columnn name `#` with `row_id`
# * Converting `claim_status`, `verified_status`, and `author_ban_status` to category:
#   * Saves memory
#   * Speeds up operations like grouping, filtering
#   * Makes the meaning of the data clearer (they’re not meant for math)
# * Converting `video_transcription_text` to string

# %%
tiktok_videos_df = data.rename(columns={'#': 'row_id'})
tiktok_videos_df['claim_status'] = tiktok_videos_df['claim_status'].astype('category')
tiktok_videos_df['verified_status'] = tiktok_videos_df['verified_status'].astype('category')
tiktok_videos_df['author_ban_status'] = tiktok_videos_df['author_ban_status'].astype('category')
tiktok_videos_df['video_transcription_text'] = tiktok_videos_df['video_transcription_text'].astype('string')
tiktok_videos_df.info()

# %% [markdown]
# ### **Task 2c. Understand the data - Investigate the variables**
#
# In this phase, you will begin to investigate the variables more closely to better understand them.
#
# You know from the project proposal that the ultimate objective is to use machine learning to classify videos as either claims or opinions. A good first step towards understanding the data might therefore be examining the `claim_status` variable. Begin by determining how many videos there are for each different claim status.

# %%
# What are the different values for claim status and how many of each are in the data?
tiktok_videos_df[['claim_status']].value_counts()

# %%
counts = tiktok_videos_df['claim_status'].value_counts()
percentages = tiktok_videos_df['claim_status'].value_counts(normalize=True) * 100

# Combine into a single DataFrame
video_type_summary = pd.DataFrame({
    'count': counts,
    'percentage': percentages.round(2)
})
video_type_summary

# %% [markdown]
# **Question:** What do you notice about the values shown?

# %% [markdown]
# **Answer:** The number of values for both statuses is quite similar.

# %% [markdown]
# Next, examine the engagement trends associated with each different claim status.
#
# Start by using Boolean masking to filter the data according to claim status, then calculate the mean and median view counts for each claim status.

# %%
# What is the average view count of videos with "claim" status?
claim_videos = tiktok_videos_df[tiktok_videos_df['claim_status'] == 'claim']
print(f"Mean view count of claim videos: {claim_videos['video_view_count'].mean()}")
print(f"Median view count of claim videos: {claim_videos['video_view_count'].median()}")

# %%
opinion_videos = tiktok_videos_df[tiktok_videos_df['claim_status'] == 'opinion']
print(f"Mean view count of opinion videos: {opinion_videos['video_view_count'].mean()}")
print(f"Median view count of opinion videos: {opinion_videos['video_view_count'].median()}")

# %% [markdown]
# **Question:** What do you notice about the mean and media within each claim category?

# %% [markdown]
# **Answer:** For both claim and opinion statuses, the mean and median values are nearly the same, but opinion videos have lower view counts compared to claim videos.

# %% [markdown]
# Now, examine trends associated with the ban status of the author.
#
# Use `groupby()` to calculate how many videos there are for each combination of categories of claim status and author ban status.

# %%
# Get counts for each group combination of claim status and author ban status
tiktok_videos_df.groupby(['claim_status', 'author_ban_status']).size()

# %% [markdown]
# **Question:** What do you notice about the number of claims videos with banned authors? Why might this relationship occur?

# %% [markdown]
# **Answer:** Even though **8817 active users** post **opinion videos**, these type of videos have only **196 banned users**. Compared to the **6566 active users** who submit **claim videos** which have **1439 banned users**. This suggests that users who make claim videos may be more likely to violate TikTok’s policies, possibly because claim videos can include misleading, unverified, or harmful information. As a result, these users may face a higher chance of being banned.

# %% [markdown]
# Continue investigating engagement levels, now focusing on `author_ban_status`.
#
# Calculate the median video share count of each author ban status.

# %%
ban_status_group = tiktok_videos_df.groupby(['author_ban_status'])
ban_status_group.agg({'video_view_count': ['mean', 'median', 'min', 'max'],
                      'video_like_count': ['mean', 'median', 'min', 'max'],
                      'video_share_count': ['mean', 'median', 'min', 'max']})

# %%
# What's the median video share count of each author ban status?
ban_status_group[['video_share_count']].median(numeric_only=True)

# %% [markdown]
# **Question:** What do you notice about the share count of banned authors, compared to that of active authors? Explore this in more depth.

# %% [markdown]
# **Answer:** Banned authors have much higher share counts than active ones. Their videos are shared more often, with a median of over **14468** compared to just **437** for active users. This may be because banned users post content that’s more attention-grabbing or controversial, which goes viral quickly before getting removed.

# %% [markdown]
# Use `groupby()` to group the data by `author_ban_status`, then use `agg()` to get the count, mean, and median of each of the following columns:
# * `video_view_count`
# * `video_like_count`
# * `video_share_count`
#
# Remember, the argument for the `agg()` function is a dictionary whose keys are columns. The values for each column are a list of the calculations you want to perform.

# %%
ban_status_group.agg({'video_view_count': ['count', 'mean', 'median', 'min', 'max'],
                      'video_like_count': ['count', 'mean', 'median', 'min', 'max'],
                      'video_share_count': ['count', 'mean', 'median', 'min', 'max']})

# %% [markdown]
# **Question:** What do you notice about the number of views, likes, and shares for banned authors compared to active authors?

# %% [markdown]
# **Answer:** Banned authors have fewer videos overall, but their videos get much more attention. On average and at the median, their view, like, and share counts are much higher than those of active users. This shows that even though banned users post less, their content tends to go more viral. For each status, the mean values are higher than median. This is probably due to a few videos having very high engagement, which pulls the average up.

# %% [markdown]
# Now, create three new columns to help better understand engagement rates:
# * `likes_per_view`: represents the number of likes divided by the number of views for each video
# * `comments_per_view`: represents the number of comments divided by the number of views for each video
# * `shares_per_view`: represents the number of shares divided by the number of views for each video

# %%
# Create a likes_per_view column
tiktok_videos_df['likes_per_view'] = tiktok_videos_df['video_like_count'] / tiktok_videos_df['video_view_count']

# Create a comments_per_view column
tiktok_videos_df['comments_per_view'] = tiktok_videos_df['video_comment_count'] / tiktok_videos_df['video_view_count']

# Create a shares_per_view column
tiktok_videos_df['shares_per_view'] = tiktok_videos_df['video_share_count'] / tiktok_videos_df['video_view_count']

tiktok_videos_df.head(10)

# %% [markdown]
# Use `groupby()` to compile the information in each of the three newly created columns for each combination of categories of claim status and author ban status, then use `agg()` to calculate the count, the mean, and the median of each group.

# %%
claim_ban_status_group = tiktok_videos_df.groupby(['claim_status', 'author_ban_status'])
claim_ban_engagement_summary_df = claim_ban_status_group.agg({'likes_per_view': ['mean', 'median', 'min', 'max'],
                                                              'comments_per_view': ['mean', 'median', 'min', 'max'],
                                                              'shares_per_view': ['mean', 'median', 'min', 'max']})
claim_ban_engagement_summary_df

# %%
# Add count separately using one column to represent all (they should all be the same)
# Align the index before assigning
count_series = claim_ban_status_group['likes_per_view'].count()
claim_ban_engagement_summary_df.insert(0, 'count', count_series)

# Flatten column names
claim_ban_engagement_summary_df.columns = [
    column[0] if column[1] == '' else f'{column[0]}_{column[1]}'
    for column in claim_ban_engagement_summary_df.columns
]

# Reset index to turn group keys into columns for a clean dataframe
claim_ban_engagement_summary_df = claim_ban_engagement_summary_df.reset_index()
claim_ban_engagement_summary_df

# %%
claim_verified_status_group = tiktok_videos_df.groupby(['claim_status', 'verified_status'])
claim_verified_engagement_summary_df = claim_verified_status_group.agg({'likes_per_view': ['mean', 'median', 'min', 'max'],
                                                                        'comments_per_view': ['mean', 'median', 'min', 'max'],
                                                                        'shares_per_view': ['mean', 'median', 'min', 'max']})
claim_verified_engagement_summary_df

# %% [markdown]
# **Question:** How does the data for claim videos and opinion videos compare or differ? Consider views, comments, likes, and shares.

# %% [markdown]
# **Answer:** Across all author statuses, claim videos generally have higher engagement metrics—views, likes, comments, and shares—compared to opinion videos. Earlier analysis suggested that banned authors tend to receive more engagement, but on closer look, their rates are only slightly higher than those of active and under-review authors. In fact, for opinion videos, banned authors actually show lower engagement rates. This suggests that engagement is not strongly linked to author status, but rather to the claim status of the content. Being banned is likely a result of the nature of the content itself, not the reason for its high engagement.
#
# ---

# %%
# Import vizualization packages
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import PercentFormatter
from matplotlib.cbook import boxplot_stats
from IPython.display import display

# Formatter to display y-axis numbers with commas
formatter = FuncFormatter(lambda x, _: f'{int(x):,}')

# Set style
sns.set(style='whitegrid')

# Group data by claim status
tiktok_videos_status_group = tiktok_videos_df.groupby(['claim_status'])

# %%
# Helper function to safely add text if value is finite
def safe_text(ax, x, y, text, **kwargs):
    if np.isfinite(y):
        ax.text(x, y, f'{text}:\n{y:.2f}', va='center', fontsize=8, **kwargs)

def group_summary_stats(grouped_df, column_name):
    # Define the aggregation functions
    agg_funcs = {
                    column_name: [lambda x: round(x.mean(), 2),
                                  'median',
                                  lambda x: x.quantile(0.25),
                                  lambda x: x.quantile(0.75),
                                  lambda x: x.quantile(0.75) - x.quantile(0.25),
                                  'min',
                                  'max']
                }

    # Perform the aggregation
    stats_df = grouped_df.agg(agg_funcs)    
    stats_df.columns = ['mean', 'median', 'Q1', 'Q3', 'IQR', 'min', 'max']

    # Reset index for clean output
    stats_df = stats_df.reset_index()

    pd.set_option('display.max_columns', None)
    return stats_df

def group_summary_stats_multi(grouped_df, column_name_label_map):
    # Derive column names
    column_names = list(column_name_label_map.keys())

    # Loop through column and label mappings
    for column_name in column_names:
        print(f'{column_name_label_map[column_name]}')

        # Call group_summary_stats to generate statistical data
        stats_df = group_summary_stats(grouped_df, column_name)
        display(stats_df)

def plot_bar_by_group(source_df,
                      x_column_name,
                      x_column_label,
                      hue_column_name,
                      hue_column_label,
                      count_label):
    # Grouped data
    grouped_data = source_df.groupby([x_column_name, hue_column_name]).size().reset_index(name='count')

    plt.figure(figsize=(10, 6))
    barplot = sns.barplot(data=grouped_data, x=x_column_name, y='count', hue=hue_column_name)

    # Manually add text labels
    for bar in barplot.patches:
        height = bar.get_height()
        x = bar.get_x() + bar.get_width() / 2   # Center the text on the bar
        plt.text(x, height + 100, int(height), ha='center', va='bottom', fontsize=9)

    plt.title(f'Distribution of {count_label} by {x_column_label} and {hue_column_label}')
    plt.xlabel(f'{x_column_label}')
    plt.ylabel(f'{count_label}')
    plt.legend(title=hue_column_label)
    plt.tight_layout()
    plt.show()

def plot_box_by_group_multi(source_df,
                            column_name_label_map,
                            **kwargs):
    
    # Extract needed arguments from keyword arguments (kwargs)
    group_by_column_name = kwargs.get('group_by_column_name')
    grouped_df = kwargs.get('grouped_df')
    
    # Derive column names
    column_names = list(column_name_label_map.keys())
    
    box_count = len(column_name_label_map)
    chart_height = box_count * 6
    fig, axes = plt.subplots(box_count, 1, figsize=(10, chart_height))

    if box_count == 1:
        axes = [axes]   # Wrap single Axes into a list
    
    if grouped_df is None:
        grouped_df = source_df.groupby([group_by_column_name])
    
    # Loop through column and label mappings
    for i, column_name in enumerate(column_names):
        # fig, ax = plt.subplots(figsize=(10, 6))
        # Plot each box
        plot_box_by_group(source_df,
                          # ax
                          axes[i],
                          column_name,
                          column_name_label_map[column_name],
                          **kwargs)
    plt.tight_layout()
    plt.subplots_adjust(hspace=0.25)
    plt.show()

def plot_box_by_group(source_df,
                      ax,
                      column_name,
                      column_label,
                      group_by_column_name,
                      group_by_column_label,
                      grouped_df=None,
                      show_legend=False):

    sns.boxplot(data=source_df, x=group_by_column_name, y=column_name, ax=ax)
    ax.yaxis.set_major_formatter(formatter)
    ax.set_title(f'Distribution of {column_label} by {group_by_column_label}')
    ax.set_xlabel(f'{group_by_column_label}')
    ax.set_ylabel(f'{column_label}')

    # Plot means
    means = grouped_df[column_name].mean()
    for i, mean in enumerate(means):
        if np.isfinite(mean):   # Safeguard against NaN, inf, -inf
            ax.scatter(i, mean, color='red', marker='D',
                       s=40, zorder=5, label='Mean' if i == 0 else "")
            ax.hlines(mean, xmin=i - 0.4, xmax=i + 0.4,
                      colors='red', linestyles='dashed', linewidth=1)
            ax.text(i, mean, f'{mean:.2f}',
                    ha='center', va='bottom', fontsize=8)

    # Calculate boxplot stats
    stats = []
    for i, (name, group) in enumerate(grouped_df):
        stats = boxplot_stats(group[column_name])[0]   # Get stats for this group

        # Min and Max (whiskers)
        safe_text(ax, i - 0.2, stats['whislo'], 'Lower Whisker', ha='right')        
        safe_text(ax, i - 0.2, stats['whishi'], 'Upper Whisker', ha='right')

        # Q1 and Q3
        safe_text(ax, i + 0.2, stats['q1'], 'Q1', ha='left')            
        safe_text(ax, i + 0.2, stats['q3'], 'Q3', ha='left')

    # Show legend only if there are labeled plot elements.
    # If no handles are found, it means all relevant values were NaN or infinite,
    # so we print an info message instead of showing an empty legend.
    if show_legend:
        handles, labels = ax.get_legend_handles_labels()
        if handles:
            ax.legend()
        else:
            print(f'[INFO] Legend not shown for "{column_label}" because all relevant values were NaN or infinite.')

def plot_box_with_stats_by_group(source_df,
                                 column_name,
                                 column_label,
                                 group_by_column_name,
                                 group_by_column_label,
                                 grouped_df=None,
                                 show_legend=False):
    fig, ax = plt.subplots(figsize=(10, 6))

    if grouped_df is None:
        grouped_df = source_df.groupby([group_by_column_name])

    # ********** Plot box chart **********
    plot_box_by_group(source_df,
                      ax,
                      column_name,
                      column_label,
                      group_by_column_name,
                      group_by_column_label,                      
                      grouped_df,
                      show_legend)
    plt.tight_layout()
    plt.show()

    # ********** Show statistical summary **********
    print(f'{column_label} per {group_by_column_label}')
    display(group_summary_stats(grouped_df, column_name))

def plot_histogram_all_and_by_group(source_df,
                                     x_column_name,
                                     x_column_label,
                                     group_by_column_name,
                                     group_by_column_label,
                                     count_label,
                                     grouped_df=None,
                                     as_percentage=False,
                                     include_overall=True):
    if include_overall:
        # ********** Plot histogram for overall data **********
        # print('\n')
        plt.figure(figsize=(12, 5))
        hist_overall = sns.histplot(source_df[x_column_name],
                                    bins=50,
                                    kde=True)
        plt.title(f'Overall Distribution of {x_column_label}')
        plt.xlabel(x_column_label)
        plt.ylabel(count_label)

        # Format x-axis as percentage (optional)
        if as_percentage:
            plt.gca().xaxis.set_major_formatter(PercentFormatter(xmax=1))

        # Rotate x-axis labels
        # plt.xticks(rotation=45)

        # Add value labels on top of bars
        for patch in hist_overall.patches:
            height = patch.get_height()
            if height > 0:
                plt.text(patch.get_x() + patch.get_width() / 2, height + 5, f'{int(height)}',
                         ha='center', va='bottom', fontsize=8, rotation=45)

        plt.tight_layout()
        plt.show()

        # ********** Show overall statistical summary **********
        print(f'Overall {x_column_label}')    
        summary_df = pd.DataFrame([
            {
                'count': source_df[x_column_name].count(),
                'mean': source_df[x_column_name].mean(),
                'median': source_df[x_column_name].median(),
                'min': source_df[x_column_name].min(),
                'max': source_df[x_column_name].max()
            }
        ])
        display(summary_df)
        print('\n')

    # ********** Plot histogram by group **********
    plt.figure(figsize=(12, 5))
    hist_by_group = sns.histplot(data=source_df, x=x_column_name, hue=group_by_column_name,
                                 bins=50, kde=True, element='bars', stat='count', common_norm=False)
    plt.title(f'Distribution of {x_column_label} by {group_by_column_label}')
    plt.xlabel(x_column_label)
    plt.ylabel(count_label)

    if hist_by_group.get_legend() is not None:
        hist_by_group.get_legend().set_title(group_by_column_label)

    # Format x-axis as percentage (optional)
    if as_percentage:
        plt.gca().xaxis.set_major_formatter(PercentFormatter(xmax=1))

    # Rotate x-axis labels
    # plt.xticks(rotation=45)

    # Add value labels per hue group
    for container in hist_by_group.containers:
        for bar in container:
            height = bar.get_height()
            if height > 0:
                hist_by_group.annotate(f'{int(height)}', xy=(bar.get_x() + bar.get_width() / 2, height),
                                       xytext=(0, 4), textcoords='offset points', ha='center',
                                       va='bottom', fontsize=8, rotation=45)
    plt.tight_layout()
    plt.show()   

    # ********** Show statistical summary by group **********
    if grouped_df is None:
        grouped_df = source_df.groupby([group_by_column_name])

    print(f'{x_column_label} by {group_by_column_label}')    
    group_summary_df = grouped_df.agg({x_column_name: ['count', 'mean', 'median', 'min', 'max']})

    # Flatten multi-level columns
    group_summary_df.columns = [f'{stat}' for stat in group_summary_df.columns.get_level_values(1)]
    group_summary_df = group_summary_df.reset_index()
    display(group_summary_df)

def plot_heatmap(source_df, column_name_label_map, title):
    plt.figure(figsize=(10, 8))

    # Derive column names
    column_names = list(column_name_label_map.keys())
    
    # Compute correlation and rename for display
    correlation = source_df[column_names].corr()
    correlation.rename(index=column_name_label_map, columns=column_name_label_map, inplace=True)

    sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
    plt.title(title)
    plt.show()

# %% [markdown]
# #### PACE: Analyze Stage Questions
#
# **Question 1:** Will the available information be sufficient to achieve the goal based on your intuition and the analysis of the variables?
#
# **Question 2:** How would you build summary dataframe statistics and assess the min and max range of the data?
#
# **Question 3:** Do the averages of any of the data variables look unusual? Can you describe the interval data?

# %% [markdown]
# **Answer 1:** Yes, the available information seems sufficient to support the early stages of building a claim classification model. The dataset includes labeled data (`claim_status`) and engagement metrics, along with user and content-level variables, which are useful for both exploratory analysis and feature development.
#
# **Answer 2:** We grouped the dataset by `claim_status` and `author_ban_status`, then calculated `mean`, `median`, `min`, and `max` for the derived engagement columns: `likes_per_view`, `comments_per_view`, and `shares_per_view`. These columns were computed earlier from raw counts. We flattened the multi-level column names and reset the index to turn the result into a readable summary dataframe, making it easy to analyze how engagement varies across claim and ban status groups.
#
# **Answer 3:** Some of the averages are noticeably higher than the medians, especially in the engagement metrics, which suggests skewness caused by a few high-performing (possibly viral or controversial) videos. The interval data reflects this, showing wide ranges—for example, `video_view_count` ranges from just 20 to nearly 1 million. Most videos have low view counts, but a small number receive very high engagement. These outliers create a wide range and pull the average up, making it higher than what most videos typically receive.

# %% [markdown]
# ### 📊 **Visualization**

# %% [markdown]
# #### Compare the count of claim vs. opinion videos by `author_ban_status`.

# %%
plot_bar_by_group(tiktok_videos_df, 'claim_status', 'Claim Status', 'author_ban_status', 'Author Status', 'Videos')

# %% [markdown]
# The chart shows the number of videos categorized by both `claim_status` and `author_ban_status`. Claim videos with active authors account for a large portion, followed by smaller but similar numbers from banned and under review authors. In contrast, most opinion videos come from active authors, with significantly fewer from banned or under review accounts. This suggests that claim content is more frequently associated with authors who face moderation, while opinion content is largely produced by active users.

# %% [markdown]
# #### Show the distribution of engagement metrics—views, likes, shares, and comments—across `claim_status` to highlight outliers and differences in medians.

# %%
plot_box_with_stats_by_group(tiktok_videos_df, 'video_view_count', 'Views',
                             'claim_status', 'Claim Status', tiktok_videos_status_group, True)

# %% [markdown]
# The chart illustrates the distribution of video views by `claim_status`. Videos with a `claim` status have a significantly higher view count than `opinion` videos, as shown by the immense difference in scale and the respective summary statistics. The `median` view count for `claim` videos is 501,555, while for `opinion` videos it is only 4,953. This indicates that `claim` videos, on average, are viewed far more frequently than `opinion` videos.

# %%
plot_box_with_stats_by_group(tiktok_videos_df, 'video_like_count', 'Likes',
                             'claim_status', 'Claim Status', tiktok_videos_status_group, True)

# %% [markdown]
# The chart displays the distribution of likes by `claim_status`. Similar to views, the number of likes for `claim` videos is substantially greater than for `opinion` videos. The `median` likes for `claim` videos are 123,649, whereas for `opinion` videos the `median` is 823. This suggests a strong correlation between video `claim_status` and the volume of likes received, with `claim` videos garnering significantly more positive engagement.

# %%
plot_box_with_stats_by_group(tiktok_videos_df, 'video_share_count', 'Shares',
                             'claim_status', 'Claim Status', tiktok_videos_status_group, True)

# %% [markdown]
# The chart shows the distribution of shares by `claim_status`. The data reveals that `claim` videos are shared much more frequently than `opinion` videos. The `median` number of shares for `claim` videos is 17,997.5, which is far greater than the `median` of 121 for `opinion` videos. This indicates that `claim` videos have a higher potential for virality and reach through sharing compared to `opinion` videos.

# %%
plot_box_with_stats_by_group(tiktok_videos_df, 'video_comment_count', 'Comments',
                             'claim_status', 'Claim Status', tiktok_videos_status_group, True)

# %% [markdown]
# The chart presents the distribution of comments by `claim_status`. The data shows a similar pattern to the other metrics, with `claim` videos receiving a much higher number of comments. The `median` comment count for `claim` videos is 286, while `opinion` videos have a `median` of only 1. This analysis suggests that `claim` videos are more effective at stimulating discussion and user engagement in the form of comments.

# %% [markdown]
# ### 📌 **Data Analyst Notes**
#
# #### Retrieving Q1, Q3, IQR, Lower Whisker, and Upper Whisker
#
# **Given observations:** `[10, 20, 30, 40, 50]`
# * `n = 5` number of observations
# * `min = 10`
# * `max = 50`
#
# ---
#
# **Quartile Formula:**
# ```
#     Q = value_at_floor + (position - floor) * (value_at_ceil - value_at_floor)
# ```
# ---
#
# #### 🔹 Q1: 25th percentile (Lower Quartile)
# ```
#     Q1 position = (n + 1) * 0.25
#                 = (5 + 1) * 0.25
#                 = 1.5
#
#     floor index           = 1
#     ceil index            = 2
#     value at floor index  = 10
#     value at ceil index   = 20
#
#     Q1 = 10 + (1.5 - 1) * (20 - 10)
#        = 10 + 0.5 * 10
#        = 15
# ```
# #### 🔹 Q3: 75th percentile (Upper Quartile)
# ```
#     Q3 position = (n + 1) * 0.75
#                 = (5 + 1) * 0.75
#                 = 4.5
#
#     floor index           = 4
#     ceil index            = 5
#     value at floor index  = 40
#     value at ceil index   = 50
#
#     Q3 = 40 + (4.5 - 4) * (50 - 40)
#        = 40 + 0.5 * 10
#        = 45
# ```
# ---
#
# #### 🔸 IQR: Interquartile Range
# ```
#     IQR = Q3 - Q1
#         = 45 - 15
#         = 30
# ```
# ---
#
# #### 🔸 Whiskers
# <span style="margin-left: 20px;font-weight: 600;">Lower whisker</span>
# ```
#     lower_whisker = Q1 - 1.5 * IQR
#                   = 15 - 1.5 * 30
#                   = 15 - 45
#                   = -30
# ```
# > Actual minimum = 10
# Since `10 ≥ -30` → lower whisker is **10**
#
# <span style="margin-left: 20px;font-weight: 600;">Upper whisker</span>
# ```
#     upper_whisker = Q3 + 1.5 * IQR
#                   = 45 + 1.5 * 30
#                   = 45 + 45
#                   = 90
# ```
# > Actual maximum = 50
# Since `50 ≤ 90` → upper whisker is **50**
#
# ---

# %% [markdown]
# #### Visualize the distribution of likes, shares, and comments per view, overall and by claim_status, to assess whether engagement patterns can help distinguish claims from opinions.

# %%
plot_histogram_all_and_by_group(tiktok_videos_df, 'likes_per_view', 'Likes per View', 
                                'claim_status', 'Claim Status', 'Videos', tiktok_videos_status_group, True)

# %% [markdown]
# The charts show the distribution of likes per view, both overall and by `claim_status`. Overall, the distribution of videos is relatively even across different "Likes per View" percentages up to around 40%, after which there is a significant drop. Videos with a `claim` status are more successful at generating likes per view than `opinion` videos. This is evidenced by the higher `mean` (0.331610 vs. 0.219802) and `median` (0.329734 vs. 0.218127) for `claim` videos. The consistent difference in `mean` and `median` values highlights a clear advantage in user engagement for `claim` videos when it comes to likes.

# %%
plot_histogram_all_and_by_group(tiktok_videos_df, 'shares_per_view', 'Shares per View', 
                                'claim_status', 'Claim Status', 'Videos', tiktok_videos_status_group, True)

# %% [markdown]
# The charts present the distribution of `shares_per_view`. The overall distribution is heavily skewed towards the lower percentages, meaning most videos have a low "Shares per View" rate. Nevertheless, `claim` videos have a higher `mean` (0.065867) and `median` (0.049673) for `shares_per_view` than `opinion` videos, which have a `mean` of 0.043699 and a `median` of 0.032487. This reveals that sharing behavior is also more prevalent for `claim` videos.

# %%
plot_histogram_all_and_by_group(tiktok_videos_df, 'comments_per_view', 'Comments per View', 
                                'claim_status', 'Claim Status', 'Videos', tiktok_videos_status_group, True)

# %% [markdown]
# The charts illustrate the distribution of `comments_per_view`. Similar to shares, the overall distribution is heavily concentrated at the lower end, indicating that most videos have a very low "Comments per View" rate. However, even within this low-engagement context, `claim` videos still generate a higher rate of comments. The `mean` "Comments per View" for `claim` videos is 0.001386, which is more than double the `mean` for `opinion` videos at 0.000516. Similarly, the `median` "Comments per View" is 0.000774 for `claim` videos and 0.000253 for `opinion` videos. This suggests that `claim` videos may be more effective at stimulating discussion and user feedback, despite the overall low volume of comments across all videos.

# %% [markdown]
# This pattern across all three engagement metrics—likes, comments, and shares—indicates that content with a claim status is consistently more effective at driving user interaction and virality.

# %% [markdown]
# #### Visualizes the relationships among five key engagement metrics: Views, Likes, Shares, Downloads, and Comments.

# %%
plot_heatmap(tiktok_videos_df,
             {
                 'video_view_count': 'Views', 'video_like_count': 'Likes', 'video_share_count': 'Shares',
                 'video_download_count': 'Downloads', 'video_comment_count': 'Comments'
             },
             'Correlation Matrix of Engagement Metrics')

# %% [markdown]
# The heatmap shows how engagement metrics—views, likes, shares, downloads, and comments—relate to one another. Most of these metrics are strongly correlated, especially likes with shares and downloads. Views also show a strong relationship with likes but a weaker one with comments.
#
# These results suggest that videos with higher engagement in one area tend to perform well in others. However, due to the high overlap, some metrics may be redundant. Creating ratios like `likes_per_view` or `shares_per_view` could help reduce noise and highlight meaningful differences in user interaction. While this analysis doesn’t directly support claim classification, it helps inform which features to focus on when building the model.

# %% [markdown]
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## **PACE: Construct**
#
# **Note**: The Construct stage does not apply to this workflow. The PACE framework can be adapted to fit the specific requirements of any project.

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## **PACE: Execute**
#
# Consider the questions in your PACE Strategy Document and those below to craft your response.

# %% [markdown]
# **Question 1:** Given your current knowledge of the data, what would you initially recommend to your manager to investigate further prior to performing exploratory data analysis?
#
# **Question 2:** What data initially presents as containing anomalies?
#
# **Question 3:** What additional types of data could strengthen this dataset?

# %% [markdown]
# **Answer 1:** To support the goal of building a model that identifies whether a video is a claim or an opinion, We recommend focusing on features that show clear differences between the two categories, such as engagement metrics—views, likes, shares, and comments. These patterns can help identify the most useful predictors for the model.
#
# **Answer 2:** Engagement metrics such as `video_view_count`, `video_like_count`, and `video_share_count` show signs of skewness due to extreme values. These high outliers may distort analysis and should be flagged for further review.
#
# **Answer 3:** Including data on the number of user reports per video, timestamps, user demographics, or content categories (e.g., politics, health, entertainment) could provide stronger context for classifying claims and understanding engagement patterns.

# %% [markdown]
# ### **Given your efforts, what can you summarize for Rosie Mae Bradshaw and the TikTok data team?**
#
# *Note for Learners: Your answer should address TikTok's request for a summary that covers the following points:*
#
# *   What percentage of the data is comprised of claims and what percentage is comprised of opinions?
# *   What factors correlate with a video's claim status?
# *   What factors correlate with a video's engagement level?

# %% [markdown]
# * From the total entries of **19382**, claims have a percentage of **50.35%** or **9608** entries, while opinions have **49.65%** or **9476** entries.
# * Major factors are the engagement metrics—views, likes, comments, and shares.
# * Claim videos consistently receive higher engagement metrics across all author statuses. Although author ban status may slightly affect engagement, it seems less influential than claim status. So, the nature of the content, especially whether it's a claim, appears to be the strongest factor linked to engagement.
# ---

# %%
tiktok_videos_df.head(10)

# %%
tiktok_videos_df.info()

# %%
tiktok_videos_df.describe()

# %% [markdown]
# ---
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
